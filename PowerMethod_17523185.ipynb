# %% [markdown]
# Tim Jaguar:
#   - Dhimas Fajarwibowo (17523185)

# %%
library('matlib')

# %%
A <- cbind(c(4, 2), c(-5, 3))
A
powerMethod(A)
# Out:
#      [,1] [,2]
# [1,] 4    -5
# [2,] 2     3
# $vector_iterations
#      v1         v2         v3         v4         v5         v6         v7
# [1,]  1 -0.1961161 -0.9125093 -0.9945355 -0.8322538 -0.1650985  0.7922966
# [2,]  1  0.9805807  0.4090559 -0.1043988 -0.5543948 -0.9862771 -0.6101361
#              v8        v9       v10        v11        v12        v13        v14
# [1,]  0.9992200 0.9125294 0.4654508 -0.5815460 -0.9806191 -0.9629192 -0.6750579
# [2,] -0.0394901 0.4090111 0.8850738  0.8135135  0.1959241 -0.2697899 -0.7377648
#             v15        v16       v17       v18        v19        v20
# [1,]  0.2673316  0.9284108 0.9912442 0.8116301 0.09602435 -0.8223131
# [2,] -0.9636046 -0.3715553 0.1320413 0.5841717 0.99537898  0.5690353
#              v21        v22        v23        v24        v25       v26
# [1,] -0.99994814 -0.8993465 -0.4131678  0.6318363  0.9865312 0.9548447
# [2,]  0.01018454 -0.4372367 -0.9106549 -0.7751019 -0.1635730 0.2971055
# ...

# %%
B <- cbind(c(0, -2, -4), c(11, 17, 26), c(-5, -7, -10))
B
powerMethod(B)
# Out:
#      [,1] [,2] [,3]
# [1,]  0   11    -5
# [2,] -2   17    -7
# [3,] -4   26   -10
# $vector_iterations
#      v1        v2        v3        v4        v5        v6        v7        v8
# [1,]  1 0.3841106 0.3478328 0.3349917 0.3294704 0.3268991 0.3256571 0.3250465
# [2,]  1 0.5121475 0.4969040 0.4913212 0.4888916 0.4877542 0.4872035 0.4869325
# [3,]  1 0.7682213 0.7950464 0.8039801 0.8077340 0.8094645 0.8102964 0.8107043
#             v9       v10       v11       v12       v13       v14       v15
# [1,] 0.3247438 0.3245931 0.3245179 0.3244804 0.3244616 0.3244522 0.3244475
# [2,] 0.4867980 0.4867311 0.4866976 0.4866809 0.4866726 0.4866684 0.4866663
# [3,] 0.8109064 0.8110069 0.8110570 0.8110821 0.8110946 0.8111009 0.8111040
#            v16       v17
# [1,] 0.3244452 0.3244440
# [2,] 0.4866653 0.4866648
# [3,] 0.8111055 0.8111063
#
# $iter
# [1] 17
#
# $vector
#           [,1]
# [1,] 0.3244434
# [2,] 0.4866645
# [3,] 0.8111067
#
# $value
# [1] 4.000011
